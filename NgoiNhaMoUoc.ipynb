# %%
import turtle
t = turtle.Turtle()
turtle.bgcolor("pink")
t.pensize(5)
t.penup()
t.goto(-350,-300)
t.pendown()

#Mặt trước
t.fillcolor('violet')
t.begin_fill()

for i in range(2):
    t.forward(210)
    t.left(90)
    t.forward(230)
    t.left(90)
t.end_fill()
#Bên cửa
t.fillcolor('green')
t.begin_fill()

for i in range(2):
    t.forward(30)
    t.left(90)
    t.forward(230)
    t.left(90)
t.end_fill()

#---------------
t.penup()
t.goto(-170,-300)
t.pendown()

#Bên cửa
t.fillcolor('green')
t.begin_fill()

for i in range(2):
    t.forward(30)
    t.left(90)
    t.forward(230)
    t.left(90)
t.end_fill()

#-----------------
t.pensize(4)
for i in range(2):
    t.left(90)
    t.forward(40)
    t.left(90)
    t.forward(150)
#-------------
# Tạo thanh sắt cửa

t.backward(30)
t.left(90)
t.forward(40)

t.left(90)
t.forward(30)
t.left(90)
t.forward(40)

t.right(90)
t.forward(30)
t.right(90)
t.forward(40)

# Tạo thanh sắt cửa
t.left(90)
t.forward(30)
t.left(90)
t.forward(40)

#-----------
t.penup()
t.goto(-290,-230)
t.pendown()

# cửa sổ
t.fillcolor("white")
t.begin_fill()
for i in range(2):
    t.left(90)
    t.forward(90)
    t.left(90)
    t.forward(70)
t.end_fill()

#----------
t.penup()
t.goto(-350,-70)
t.pendown()
t.left(150)

# Vẽ mái
t.fillcolor("blue")
t.begin_fill()
t.forward(210)
t.right(120)
t.forward(210)
t.end_fill()
t.right(30)

#-----
t.penup()
t.goto(-140,-270)
t.pendown()

# thân nhà
t.fillcolor('yellow')
t.pencolor("black")
t.pensize(5)
t.begin_fill()
for i in range(2):
    t.left(90)
    t.forward(300)
    t.left(90)
    t.forward(200)
t.end_fill()

#---------

t.penup()
t.goto(-80,-270)
t.pendown()

# Cửa thân nhà
t.fillcolor("white")
t.begin_fill()
for i in range(2):
    t.left(90)
    t.forward(90)
    t.left(90)
    t.forward(140)
t.end_fill()

t.penup()
t.goto(-60,-200)
t.pendown()

for i in range(2):
    t.left(90)
    t.forward(50)
    t.left(90)
    t.forward(50)

t.penup()
t.goto(-10,-223)
t.pendown()
t.circle(2)

t.penup()
t.goto(60,-223)
t.pendown()
#----------

t.fillcolor("white")
t.begin_fill()
for i in range(2):
    t.left(90)
    t.forward(60)
    t.left(90)
    t.forward(90)
t.end_fill()

#----
t.penup()
t.goto(160,-70)
t.pendown()

t.fillcolor("green")
t.begin_fill()
t.left(90)
t.forward(40)
t.left(90)
t.forward(40)
t.left(90)
t.forward(366)
t.end_fill()

#-----------
t.penup()
t.goto(160,-70)
t.pendown()

t.fillcolor("green")
t.begin_fill()
t.forward(300)
t.right(60)
t.forward(49)
t.end_fill()

#---------
#Hoàn thiện mái xanh ngang
t.penup()
t.goto(200,-30)
t.pendown()
t.left(60)
t.forward(358)
#====
t.penup()
t.goto(-165,-28)
t.pendown()

t.fillcolor("red")
t.pencolor("red")
t.pensize(2)
t.begin_fill()
t.right(90)
t.forward(130)
t.left(90)
t.forward(75)
t.end_fill()

#Mái đỏ lớn
t.penup()
t.goto(201,-30)
t.pendown()
t.right(90)
t.fillcolor("red")
t.pencolor("red")
t.begin_fill()
for i in range(2):
    t.forward(132)
    t.left(90)
    t.forward(365)
    t.left(90)
t.end_fill()

# Bậc thang
t.pencolor("black")
t.penup()
t.goto(-90,-270)
t.pendown()
t.pensize(2)
t.backward(15)
t.right(90)

t.forward(110)
t.left(90)
t.forward(15)

t.penup()
t.goto(-100,-285)
t.pendown()
t.right(90)

t.forward(130)
t.right(90)
t.forward(15)
t.right(90)
t.forward(130)
t.right(90)
t.forward(15)

#----------
# Vẽ câyy
#thân cây
t.penup()
t.goto(500,-300)
t.pendown()
t.right(90)

t.fillcolor("brown")
t.begin_fill()
for i in range(2):
    t.forward(60)
    t.left(90)
    t.forward(200)
    t.left(90)
t.end_fill()


t.penup()
t.goto(450,-100)
t.pendown()

#Tán cây
t.fillcolor('green')
t.begin_fill()
t.forward(160)
t.left(120)
t.forward(160)
t.left(120)
t.forward(160)
t.end_fill()

t.penup()
t.goto(450,-5)
t.pendown()
t.left(120)

t.fillcolor('green')
t.begin_fill()
t.forward(160)
t.left(120)
t.forward(160)
t.left(120)
t.forward(160)
t.end_fill()

t.penup()
t.goto(450,80)
t.pendown()
t.left(120)

t.fillcolor('green')
t.begin_fill()
t.forward(160)
t.left(120)
t.forward(160)
t.left(120)
t.forward(160)
t.end_fill()

# Ông mặt trời.
t.penup()
t.goto(600,340)
t.pendown()
t.fillcolor("yellow")
t.begin_fill()
t.circle(60)
t.end_fill()
turtle.done()
